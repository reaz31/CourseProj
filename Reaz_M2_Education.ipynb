# %% [markdown]
# <a href="https://colab.research.google.com/github/reaz31/CourseProj/blob/main/Reaz_M2_Education.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # MSDS 430 Final Project - Does the expenditure of Midwest  States effect 8th Grade Average Reading Scores.

# %% [markdown]
# I would like to focus on just midwest states and see how revenue and expenses have affected outcomes of test results in just 8th grade; for a certain number of years for the following 12 states: Illinois, Indiana, Iowa, Kansas, Michigan, Minnesota, Missouri, Nebraska, North Dakota, Ohio, South Dakota, and Wisconsin. A lot of information can be obtained from this as the midwest has a good balance of cities and rural areas.

# %% [markdown]
# Step 2 (5 pts.): Read in your data file and use pandas and clean up your data as needed. Extract only what you will be using for this project and demonstrate this by creating a nicely formatted table of the first 20 rows of data relevant to your needs for the project. Each column should align nicely and be clearly labeled. Remember to include any relevant comments within your code.

# %%
import pandas as pd
filename = pd.read_csv('states_all.csv')

# I am removing all columns which don;t show any thing related to 8th grade. I will just be focusing on 8th grade
# and the expense and revenue.
# I understand there are some missing values and I will have to figure out a way to replace them and make sure its not a 0
#because then my averages will be off.

filename.drop('ENROLL', axis =1, inplace = True)
filename.drop('GRADES_PK_G', axis =1, inplace = True)
filename.drop('GRADES_KG_G', axis =1, inplace = True)
filename.drop('GRADES_4_G', axis =1, inplace = True)
filename.drop('GRADES_12_G', axis =1, inplace = True)
filename.drop('GRADES_1_8_G', axis =1, inplace = True)
filename.drop('GRADES_9_12_G', axis =1, inplace = True)
filename.drop('GRADES_ALL_G', axis =1, inplace = True)
f#!/usr/bin/env python
# coding: utf-8

# # MSDS 430 Final Project - Does the expenditure of Midwest  States effect 8th Grade Average Reading Scores.

# I would like to focus on just midwest states and see how revenue and expenses have affected outcomes of test results in just 8th grade; for a certain number of years for the following 12 states: Illinois, Indiana, Iowa, Kansas, Michigan, Minnesota, Missouri, Nebraska, North Dakota, Ohio, South Dakota, and Wisconsin. A lot of information can be obtained from this as the midwest has a good balance of cities and rural areas.

# Step 2 (5 pts.): Read in your data file and use pandas and clean up your data as needed. Extract only what you will be using for this project and demonstrate this by creating a nicely formatted table of the first 20 rows of data relevant to your needs for the project. Each column should align nicely and be clearly labeled. Remember to include any relevant comments within your code.

# In[111]:


import pandas as pd
filename = pd.read_csv('states_all.csv')

# I am removing all columns which don;t show any thing related to 8th grade. I will just be focusing on 8th grade
# and the expense and revenue.
# I understand there are some missing values and I will have to figure out a way to replace them and make sure its not a 0
#because then my averages will be off.

filename.drop('ENROLL', axis =1, inplace = True)
filename.drop('GRADES_PK_G', axis =1, inplace = True)
filename.drop('GRADES_KG_G', axis =1, inplace = True)
filename.drop('GRADES_4_G', axis =1, inplace = True)
filename.drop('GRADES_12_G', axis =1, inplace = True)
filename.drop('GRADES_1_8_G', axis =1, inplace = True)
filename.drop('GRADES_9_12_G', axis =1, inplace = True)
filename.drop('GRADES_ALL_G', axis =1, inplace = True)
filename.drop('AVG_MATH_4_SCORE', axis =1, inplace = True)
filename.drop('AVG_READING_4_SCORE', axis =1, inplace = True)
filename.drop('AVG_MATH_8_SCORE', axis =1, inplace = True)
# There are some values not reported the score for YEAR 2000 for IL and MI, I will be omitting this from further data so it
#will not mess up the actual averages.
filename.head(19)


# Step 3 (5 pts.): Use numpy and the cleaned data to perform several calculations relevant to your final project. Explain each calculation by including comments within your code. Your output should clearly state what each calculation is, i.e. "The mean height of those in the data is X"

# In[112]:


#I have created a dataframe for each of the 12 states to further the analysis


import numpy as np

IllinoisScore_Reading = ['PRIMARY_KEY','YEAR','STATE','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
il = filename[IllinoisScore_Reading].iloc[1:8]

IndianaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
indy = filename[IndianaScore_Reading].iloc[8:16]

IowaScore_Reading = ['PRIMARY_KEY','YEAR','STATE','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
iw = filename[IowaScore_Reading].iloc[16:24]

KansasScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
ks = filename[KansasScore_Reading].iloc[24:32]

MichiganScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
mi = filename[MichiganScore_Reading].iloc[33:40]

MinnesotaScore_Reading =  ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
mn = filename[MinnesotaScore_Reading].iloc[40:48]

MissouriScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
mo = filename[MissouriScore_Reading].iloc[48:56]

NebraskaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
nb = filename[NebraskaScore_Reading].iloc[56:64]

NorthDakotaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
nd = filename[NorthDakotaScore_Reading].iloc[64:72]

OhioScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
oh = filename[OhioScore_Reading].iloc[72:80]

SouthDakotaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
sd = filename[SouthDakotaScore_Reading].iloc[80:88]

WisconsinScore_Reading =['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
wi = filename[WisconsinScore_Reading].iloc[88:96]

All_Reading =['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
all_states = filename[All_Reading].iloc[0:96]


# In[113]:


#I would like to calculate the average expense per state and graph them all on one graph for an initial comparison.
import numpy as np

IllinoisScore_eAVG = il.TOTAL_EXPENDITURE
IL_expenditure = np.average(IllinoisScore_eAVG)
IL_expenditureA = '{:0,.2f}'.format(IL_expenditure)
#print(IL_expenditure)


IndianaScore_eAVG = indy.TOTAL_EXPENDITURE
IN_expenditure = np.average(IndianaScore_eAVG)
IN_expenditureA = '{:0,.2f}'.format(IN_expenditure)
#print(IN_expenditure)

IowaScore_eAVG = iw.TOTAL_EXPENDITURE
IW_expenditure = np.average(IowaScore_eAVG)
IW_expenditureA = '{:0,.2f}'.format(IW_expenditure)

KansasScore_eAVG = ks.TOTAL_EXPENDITURE
KS_expenditure = np.average(KansasScore_eAVG)
KS_expenditureA = '{:0,.2f}'.format(KS_expenditure)

MichiganScore_eAVG = mi.TOTAL_EXPENDITURE
MI_expenditure = np.average(MichiganScore_eAVG)
MI_expenditureA = '{:0,.2f}'.format(MI_expenditure)

MinnesotaScore_eAVG = mn.TOTAL_EXPENDITURE
MN_expenditure = np.average(MinnesotaScore_eAVG)
MN_expenditureA = '{:0,.2f}'.format(MN_expenditure)

MissouriScore_eAVG = mo.TOTAL_EXPENDITURE
MO_expenditure = np.average(MissouriScore_eAVG)
MO_expenditureA = '{:0,.2f}'.format(MO_expenditure)

NebraskaScore_eAVG = nb.TOTAL_EXPENDITURE
NE_expenditure = np.average(NebraskaScore_eAVG)
NE_expenditureA = '{:0,.2f}'.format(NE_expenditure)

NorthDakotaScore_eAVG= nd.TOTAL_EXPENDITURE
ND_expenditure = np.average(NorthDakotaScore_eAVG)
ND_expenditureA = '{:0,.2f}'.format(ND_expenditure)

OhioScore_eAVG = oh.TOTAL_EXPENDITURE
OH_expenditure = np.average(OhioScore_eAVG)
OH_expenditureA = '{:0,.2f}'.format(OH_expenditure)

SouthDakotaScore_eAVG = sd.TOTAL_EXPENDITURE
SD_expenditure = np.average(SouthDakotaScore_eAVG)
SD_expenditureA = '{:0,.2f}'.format(SD_expenditure)

WisconsinScore_eAVG = wi.TOTAL_EXPENDITURE
WI_expenditure = np.average(WisconsinScore_eAVG)
WI_expenditureA = '{:0,.2f}'.format(WI_expenditure)


class CalcAvg:
    
    def __init__(self, state, average):
        
        self.state = state
        self.average = average
        
    def __str__(self):
  
        return 'The average amount of Expenditure for ' + self.state +  " between 2000 - 2015 is $"  + str(self.average)

IL_AVG = CalcAvg( "Illinois", IL_expenditureA)
print (IL_AVG)

IN_AVG = CalcAvg( "Indiana", IN_expenditureA)
print (IN_AVG)   

IW_AVG = CalcAvg( "Iowa", IW_expenditureA)
print (IW_AVG)

KS_AVG = CalcAvg( "Kansas", KS_expenditureA)
print (KS_AVG)

OH_AVG = CalcAvg( "Ohio", OH_expenditureA)
print (OH_AVG)

MI_AVG = CalcAvg( "Michigan", MI_expenditureA)
print (MI_AVG)

MN_AVG = CalcAvg( "Minnesota", MN_expenditureA)
print (MN_AVG)

MO_AVG = CalcAvg( "Missouri", MO_expenditureA)
print (MO_AVG)

NE_AVG = CalcAvg( "Nebraska", NE_expenditureA)
print (NE_AVG)

ND_AVG = CalcAvg( "North Dakota", ND_expenditureA)
print (ND_AVG)

SD_AVG = CalcAvg( "South Dakota", SD_expenditureA)
print (SD_AVG)

WI_AVG = CalcAvg( "Wisconsin", WI_expenditureA)
print (WI_AVG)


# In[114]:


import numpy as np
#I would like to calculate the average revenue per state and graph them all on one graph for an initial comparison.

IllinoisScore_rAVG = il.TOTAL_REVENUE
IL_rev = np.average(IllinoisScore_rAVG)
IL_revA = '{:0,.2f}'.format(IL_rev)
#print(IL_expenditure)


IndianaScore_rAVG = indy.TOTAL_REVENUE
IN_rev = np.average(IndianaScore_rAVG)
IN_revA = '{:0,.2f}'.format(IN_rev)
#print(IN_expenditure)

IowaScore_rAVG = iw.TOTAL_REVENUE
IW_rev = np.average(IowaScore_rAVG)
IW_revA = '{:0,.2f}'.format(IW_rev)

KansasScore_rAVG = ks.TOTAL_REVENUE
KS_rev = np.average(KansasScore_rAVG)
KS_revA = '{:0,.2f}'.format(KS_rev)

MichiganScore_rAVG = mi.TOTAL_REVENUE
MI_rev = np.average(MichiganScore_rAVG)
MI_revA = '{:0,.2f}'.format(MI_rev)

MinnesotaScore_rAVG = mn.TOTAL_REVENUE
MN_rev = np.average(MinnesotaScore_rAVG)
MN_revA = '{:0,.2f}'.format(MN_rev)

MissouriScore_rAVG = mo.TOTAL_REVENUE
MO_rev = np.average(MissouriScore_rAVG)
MO_revA = '{:0,.2f}'.format(MO_rev)

NebraskaScore_rAVG = nb.TOTAL_REVENUE
NE_rev = np.average(NebraskaScore_rAVG)
NE_revA = '{:0,.2f}'.format(NE_rev)

NorthDakotaScore_rAVG= nd.TOTAL_REVENUE
ND_rev = np.average(NorthDakotaScore_rAVG)
ND_revA = '{:0,.2f}'.format(ND_rev)

OhioScore_rAVG = oh.TOTAL_REVENUE
OH_rev = np.average(OhioScore_rAVG)
OH_revA = '{:0,.2f}'.format(OH_rev)

SouthDakotaScore_rAVG = sd.TOTAL_REVENUE
SD_rev = np.average(SouthDakotaScore_rAVG)
SD_revA = '{:0,.2f}'.format(SD_rev)

WisconsinScore_rAVG = wi.TOTAL_REVENUE
WI_rev = np.average(WisconsinScore_rAVG)
WI_revA = '{:0,.2f}'.format(WI_rev)

class CalcAvg:
    
    def __init__(self, state, average):
        
        self.state = state
        self.average = average
        
    def __str__(self):
  
        return 'The average amount of Revenue for ' + self.state +  " between 2000 - 2015 is $"  + str(self.average)
    
       
IL_rAVG = CalcAvg( "Illinois", IL_revA)
print (IL_rAVG)

IN_rAVG = CalcAvg( "Indiana", IN_revA)
print (IN_rAVG)

IW_rAVG = CalcAvg( "Iowa", IW_revA)
print (IW_rAVG)

KS_rAVG = CalcAvg( "Kansas", KS_revA)
print (KS_rAVG)

MI_rAVG = CalcAvg( "Michigan", MI_revA)
print (MI_rAVG)

MN_rAVG = CalcAvg( "Minnesota", MN_revA)
print (MN_rAVG)

MO_rAVG = CalcAvg( "Missouri", MO_revA)
print (MO_rAVG)

NE_rAVG = CalcAvg( "Nebraska", NE_revA)
print (NE_rAVG)

ND_rAVG = CalcAvg( "North Dakota", ND_revA)
print (ND_rAVG)

OH_rAVG = CalcAvg( "Ohio", OH_revA)
print (OH_rAVG)

SD_rAVG = CalcAvg( "South Dakota", SD_revA)
print (SD_rAVG)

WI_rAVG = CalcAvg( "Wisconsin", WI_revA)
print (WI_rAVG)



# In[115]:



from operator import itemgetter
from collections import OrderedDict

#I want to first start with compiling a list of all the averages for expenditure and revenue.
L_REV = {"ND" : ND_revA, "SD":  SD_revA, "NE": NE_revA, "KS": KS_revA, "IW":IW_revA,  "MO":MO_revA, "MN":MN_revA, "WI" :WI_revA, "IN": IN_revA, "MI":MI_revA, "OH": OH_revA,  "IL" : IL_revA}

print(L_REV)

L_EXP = {"SD" : SD_expenditureA,  "ND": ND_expenditureA,  "NE": NE_expenditureA, "KS": KS_expenditureA, "IW": IW_expenditureA,  "MO":MO_expenditureA, "MN":MN_expenditureA, "WI": WI_expenditureA, "IN": IN_expenditureA, "MI": MI_expenditureA, "OH" : OH_expenditureA, "IL" : IL_expenditureA}

print(L_EXP)

# I have sorted them in increasing order with the help of excel, as I was having trouble doing this in Python with using a dictionary.


# In[116]:


import matplotlib
from matplotlib import pyplot as plt

AvgRevenueByState = plt.bar( range(len(L_REV)),L_REV.values(), align='center') 
plt.xticks(range(len(L_REV)), list(L_REV.keys()))
plt.title("Average Revenue per State from 2000 - 2015")
plt.xlabel("State")
plt.ylabel("Revenue")
plt.show()

AvgExpenseByState = plt.bar( range(len(L_EXP)),L_EXP.values(), align='center') 
plt.xticks(range(len(L_EXP)), list(L_EXP.keys()))
plt.title("Average Expense per State from 2000 - 2015")
plt.xlabel("State")
plt.ylabel("EXPENSE")
plt.show()

# so the revenue and expense is relativley within the same range in average in all 12 states. 


# In[117]:


#Next I will graph all reading scores for the 12 states from 2000-2015 and will examine in detail the minimum values and maximum values for the scores in different years.
from numpy import *
import math
import matplotlib.pyplot as plt

ILReading = plt.plot(il.YEAR, il.AVG_READING_8_SCORE) # blue
OHReading = plt.plot(oh.YEAR, oh.AVG_READING_8_SCORE) # orange
MNReading = plt.plot(mn.YEAR, mn.AVG_READING_8_SCORE) #green
WIReading = plt.plot(wi.YEAR, wi.AVG_READING_8_SCORE) #red
MIReading = plt.plot(mi.YEAR, mi.AVG_READING_8_SCORE) #purple
INReading = plt.plot(indy.YEAR, indy.AVG_READING_8_SCORE) #brown
plt.title("Average Reading Scores - 8TH GRADE") 
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

NEReading = plt.plot(nb.YEAR, nb.AVG_READING_8_SCORE) # blue
ksReading = plt.plot(ks.YEAR, ks.AVG_READING_8_SCORE) # orange
IWReading = plt.plot(iw.YEAR, iw.AVG_READING_8_SCORE) #green
MOReading = plt.plot(mo.YEAR, mo.AVG_READING_8_SCORE) #red
SDReading = plt.plot(sd.YEAR, sd.AVG_READING_8_SCORE) #purple
NDReading = plt.plot(nd.YEAR, nd.AVG_READING_8_SCORE) #brown
plt.title("Average Reading Scores - 8TH GRADE") 
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()


# In[120]:


import matplotlib
from matplotlib import pyplot as plt
# I plotted each graph by state to compare revenue and expense along with the reading score reported. 

ILReading = plt.plot(il.YEAR, il.AVG_READING_8_SCORE) 
plt.title("IL Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ILExp = plt.plot(il.YEAR, il.TOTAL_EXPENDITURE) #blue
ILREV = plt.plot(il.YEAR, il.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for IL")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()


################################################

nbReading = plt.plot(nb.YEAR, nb.AVG_READING_8_SCORE) 

plt.title("Neberaska Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

nbExp = plt.plot(nb.YEAR, nb.TOTAL_EXPENDITURE)#blue
nbREV = plt.plot(nb.YEAR, nb.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Nebereska")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

MOReading = plt.plot(mo.YEAR, mo.AVG_READING_8_SCORE) 
plt.title("MO Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

MOExp = plt.plot(mo.YEAR, mo.TOTAL_EXPENDITURE)#blue
moREV = plt.plot(mo.YEAR, mo.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Moussouri")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

IWReading = plt.plot(iw.YEAR, iw.AVG_READING_8_SCORE) 
plt.title("IW Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

IWExp = plt.plot(iw.YEAR, iw.TOTAL_EXPENDITURE)#blue
IWREV = plt.plot(iw.YEAR, iw.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Iowa")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()


################################################

miReading = plt.plot(mi.YEAR, mi.AVG_READING_8_SCORE) 
plt.title("MI Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

miExp = plt.plot(mi.YEAR, mi.TOTAL_EXPENDITURE) #blue
miREV = plt.plot(mi.YEAR, mi.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Michigan")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

sdReading = plt.plot(sd.YEAR, sd.AVG_READING_8_SCORE) 
plt.title("SD Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

sdExp = plt.plot(sd.YEAR, sd.TOTAL_EXPENDITURE) #blue
sdREV = plt.plot(sd.YEAR, sd.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for South Dakota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

ndReading = plt.plot(nd.YEAR, nd.AVG_READING_8_SCORE) 
plt.title("ND Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ndExp = plt.plot(nd.YEAR, nd.TOTAL_EXPENDITURE) #blue
ndREV = plt.plot(nd.YEAR, nd.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for North Dakota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

indyReading = plt.plot(indy.YEAR, indy.AVG_READING_8_SCORE) 
plt.title("INDY Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

indyExp = plt.plot(indy.YEAR, indy.TOTAL_EXPENDITURE)#blue
indyREV = plt.plot(indy.YEAR, indy.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for INDIANA")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


OhReading = plt.plot(oh.YEAR, oh.AVG_READING_8_SCORE) 
plt.title("Ohio Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

OHExp = plt.plot(oh.YEAR, oh.TOTAL_EXPENDITURE) #blue
OHREV = plt.plot(oh.YEAR, oh.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Ohio")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


wiReading = plt.plot(wi.YEAR, wi.AVG_READING_8_SCORE) 
plt.title("Wisconsin Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

wiExp = plt.plot(wi.YEAR, wi.TOTAL_EXPENDITURE) #blue
WIREV = plt.plot(wi.YEAR, wi.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Wisconsin")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


mnReading = plt.plot(mn.YEAR, mn.AVG_READING_8_SCORE) 
plt.title("MN Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

mnExp = plt.plot(mn.YEAR, mn.TOTAL_EXPENDITURE)#blue
mnREV = plt.plot(mn.YEAR, mn.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Minnisota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


ksReading = plt.plot(ks.YEAR, ks.AVG_READING_8_SCORE) 
plt.title("Kansas Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ksExp = plt.plot(ks.YEAR, ks.TOTAL_EXPENDITURE)#blue
ksREV = plt.plot(ks.YEAR, ks.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Kansas")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()


# In[ ]:




ilename.drop('AVG_MATH_4_SCORE', axis =1, inplace = True)
filename.drop('AVG_READING_4_SCORE', axis =1, inplace = True)
filename.drop('AVG_MATH_8_SCORE', axis =1, inplace = True)
# There are some values not reported the score for YEAR 2000 for IL and MI, I will be omitting this from further data so it
#will not mess up the actual averages.
filename.head(19)
# Out:
#       PRIMARY_KEY     STATE  YEAR  TOTAL_REVENUE  TOTAL_EXPENDITURE  \
# 0   2000_ILLINOIS  ILLINOIS  2000       17595047           18073190
# 1   2003_ILLINOIS  ILLINOIS  2003       19627346           21278177
# 2   2005_ILLINOIS  ILLINOIS  2005       21611180           22035569
# 3   2007_ILLINOIS  ILLINOIS  2007       23897153           23401917
# 4   2009_ILLINOIS  ILLINOIS  2009       26987426           27716187
# 5   2011_ILLINOIS  ILLINOIS  2011       29507584           28525858
# 6   2013_ILLINOIS  ILLINOIS  2013       30057886           29517831
# 7   2015_ILLINOIS  ILLINOIS  2015       32096832           32410033
# 8    2000_INDIANA   INDIANA  2000        8489991            8518477
# 9    2003_INDIANA   INDIANA  2003        8246076            9777720
# 10   2005_INDIANA   INDIANA  2005       11653165           11071431
# 11   2007_INDIANA   INDIANA  2007       10458932           11462062
# 12   2009_INDIANA   INDIANA  2009       12999357           11218398
# ...

# %% [markdown]
# Step 3 (5 pts.): Use numpy and the cleaned data to perform several calculations relevant to your final project. Explain each calculation by including comments within your code. Your output should clearly state what each calculation is, i.e. "The mean height of those in the data is X"

# %%
#I have created a dataframe for each of the 12 states to further the analysis


import numpy as np

IllinoisScore_Reading = ['PRIMARY_KEY','YEAR','STATE','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
il = filename[IllinoisScore_Reading].iloc[1:8]

IndianaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
indy = filename[IndianaScore_Reading].iloc[8:16]

IowaScore_Reading = ['PRIMARY_KEY','YEAR','STATE','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
iw = filename[IowaScore_Reading].iloc[16:24]

KansasScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
ks = filename[KansasScore_Reading].iloc[24:32]

MichiganScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
mi = filename[MichiganScore_Reading].iloc[33:40]

MinnesotaScore_Reading =  ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
mn = filename[MinnesotaScore_Reading].iloc[40:48]

MissouriScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
mo = filename[MissouriScore_Reading].iloc[48:56]

NebraskaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
nb = filename[NebraskaScore_Reading].iloc[56:64]

NorthDakotaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
nd = filename[NorthDakotaScore_Reading].iloc[64:72]

OhioScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
oh = filename[OhioScore_Reading].iloc[72:80]

SouthDakotaScore_Reading = ['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE','TOTAL_REVENUE']
sd = filename[SouthDakotaScore_Reading].iloc[80:88]

WisconsinScore_Reading =['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
wi = filename[WisconsinScore_Reading].iloc[88:96]

All_Reading =['PRIMARY_KEY','STATE','YEAR','AVG_READING_8_SCORE','TOTAL_EXPENDITURE', 'TOTAL_REVENUE']
all_states = filename[All_Reading].iloc[0:96]

# %%
#I would like to calculate the average expense per state and graph them all on one graph for an initial comparison.
import numpy as np

IllinoisScore_eAVG = il.TOTAL_EXPENDITURE
IL_expenditure = np.average(IllinoisScore_eAVG)
IL_expenditureA = '{:0,.2f}'.format(IL_expenditure)
#print(IL_expenditure)


IndianaScore_eAVG = indy.TOTAL_EXPENDITURE
IN_expenditure = np.average(IndianaScore_eAVG)
IN_expenditureA = '{:0,.2f}'.format(IN_expenditure)
#print(IN_expenditure)

IowaScore_eAVG = iw.TOTAL_EXPENDITURE
IW_expenditure = np.average(IowaScore_eAVG)
IW_expenditureA = '{:0,.2f}'.format(IW_expenditure)

KansasScore_eAVG = ks.TOTAL_EXPENDITURE
KS_expenditure = np.average(KansasScore_eAVG)
KS_expenditureA = '{:0,.2f}'.format(KS_expenditure)

MichiganScore_eAVG = mi.TOTAL_EXPENDITURE
MI_expenditure = np.average(MichiganScore_eAVG)
MI_expenditureA = '{:0,.2f}'.format(MI_expenditure)

MinnesotaScore_eAVG = mn.TOTAL_EXPENDITURE
MN_expenditure = np.average(MinnesotaScore_eAVG)
MN_expenditureA = '{:0,.2f}'.format(MN_expenditure)

MissouriScore_eAVG = mo.TOTAL_EXPENDITURE
MO_expenditure = np.average(MissouriScore_eAVG)
MO_expenditureA = '{:0,.2f}'.format(MO_expenditure)

NebraskaScore_eAVG = nb.TOTAL_EXPENDITURE
NE_expenditure = np.average(NebraskaScore_eAVG)
NE_expenditureA = '{:0,.2f}'.format(NE_expenditure)

NorthDakotaScore_eAVG= nd.TOTAL_EXPENDITURE
ND_expenditure = np.average(NorthDakotaScore_eAVG)
ND_expenditureA = '{:0,.2f}'.format(ND_expenditure)

OhioScore_eAVG = oh.TOTAL_EXPENDITURE
OH_expenditure = np.average(OhioScore_eAVG)
OH_expenditureA = '{:0,.2f}'.format(OH_expenditure)

SouthDakotaScore_eAVG = sd.TOTAL_EXPENDITURE
SD_expenditure = np.average(SouthDakotaScore_eAVG)
SD_expenditureA = '{:0,.2f}'.format(SD_expenditure)

WisconsinScore_eAVG = wi.TOTAL_EXPENDITURE
WI_expenditure = np.average(WisconsinScore_eAVG)
WI_expenditureA = '{:0,.2f}'.format(WI_expenditure)


class CalcAvg:
    
    def __init__(self, state, average):
        
        self.state = state
        self.average = average
        
    def __str__(self):
  
        return 'The average amount of Expenditure for ' + self.state +  " between 2000 - 2015 is $"  + str(self.average)

IL_AVG = CalcAvg( "Illinois", IL_expenditureA)
print (IL_AVG)

IN_AVG = CalcAvg( "Indiana", IN_expenditureA)
print (IN_AVG)   

IW_AVG = CalcAvg( "Iowa", IW_expenditureA)
print (IW_AVG)

KS_AVG = CalcAvg( "Kansas", KS_expenditureA)
print (KS_AVG)

OH_AVG = CalcAvg( "Ohio", OH_expenditureA)
print (OH_AVG)

MI_AVG = CalcAvg( "Michigan", MI_expenditureA)
print (MI_AVG)

MN_AVG = CalcAvg( "Minnesota", MN_expenditureA)
print (MN_AVG)

MO_AVG = CalcAvg( "Missouri", MO_expenditureA)
print (MO_AVG)

NE_AVG = CalcAvg( "Nebraska", NE_expenditureA)
print (NE_AVG)

ND_AVG = CalcAvg( "North Dakota", ND_expenditureA)
print (ND_AVG)

SD_AVG = CalcAvg( "South Dakota", SD_expenditureA)
print (SD_AVG)

WI_AVG = CalcAvg( "Wisconsin", WI_expenditureA)
print (WI_AVG)
# Out:
# The average amount of Expenditure for Illinois between 2000 - 2015 is $26,412,224.57
# The average amount of Expenditure for Indiana between 2000 - 2015 is $10,718,917.50
# The average amount of Expenditure for Iowa between 2000 - 2015 is $5,396,462.75
# The average amount of Expenditure for Kansas between 2000 - 2015 is $4,916,625.25
# The average amount of Expenditure for Ohio between 2000 - 2015 is $20,600,961.88
# The average amount of Expenditure for Michigan between 2000 - 2015 is $19,097,626.43
# The average amount of Expenditure for Minnesota between 2000 - 2015 is $10,063,233.75
# The average amount of Expenditure for Missouri between 2000 - 2015 is $9,080,313.12
# The average amount of Expenditure for Nebraska between 2000 - 2015 is $3,251,651.88
# The average amount of Expenditure for North Dakota between 2000 - 2015 is $1,187,068.25
# The average amount of Expenditure for South Dakota between 2000 - 2015 is $1,183,715.50
# ...

# %%
import numpy as np
#I would like to calculate the average revenue per state and graph them all on one graph for an initial comparison.

IllinoisScore_rAVG = il.TOTAL_REVENUE
IL_rev = np.average(IllinoisScore_rAVG)
IL_revA = '{:0,.2f}'.format(IL_rev)
#print(IL_expenditure)


IndianaScore_rAVG = indy.TOTAL_REVENUE
IN_rev = np.average(IndianaScore_rAVG)
IN_revA = '{:0,.2f}'.format(IN_rev)
#print(IN_expenditure)

IowaScore_rAVG = iw.TOTAL_REVENUE
IW_rev = np.average(IowaScore_rAVG)
IW_revA = '{:0,.2f}'.format(IW_rev)

KansasScore_rAVG = ks.TOTAL_REVENUE
KS_rev = np.average(KansasScore_rAVG)
KS_revA = '{:0,.2f}'.format(KS_rev)

MichiganScore_rAVG = mi.TOTAL_REVENUE
MI_rev = np.average(MichiganScore_rAVG)
MI_revA = '{:0,.2f}'.format(MI_rev)

MinnesotaScore_rAVG = mn.TOTAL_REVENUE
MN_rev = np.average(MinnesotaScore_rAVG)
MN_revA = '{:0,.2f}'.format(MN_rev)

MissouriScore_rAVG = mo.TOTAL_REVENUE
MO_rev = np.average(MissouriScore_rAVG)
MO_revA = '{:0,.2f}'.format(MO_rev)

NebraskaScore_rAVG = nb.TOTAL_REVENUE
NE_rev = np.average(NebraskaScore_rAVG)
NE_revA = '{:0,.2f}'.format(NE_rev)

NorthDakotaScore_rAVG= nd.TOTAL_REVENUE
ND_rev = np.average(NorthDakotaScore_rAVG)
ND_revA = '{:0,.2f}'.format(ND_rev)

OhioScore_rAVG = oh.TOTAL_REVENUE
OH_rev = np.average(OhioScore_rAVG)
OH_revA = '{:0,.2f}'.format(OH_rev)

SouthDakotaScore_rAVG = sd.TOTAL_REVENUE
SD_rev = np.average(SouthDakotaScore_rAVG)
SD_revA = '{:0,.2f}'.format(SD_rev)

WisconsinScore_rAVG = wi.TOTAL_REVENUE
WI_rev = np.average(WisconsinScore_rAVG)
WI_revA = '{:0,.2f}'.format(WI_rev)

class CalcAvg:
    
    def __init__(self, state, average):
        
        self.state = state
        self.average = average
        
    def __str__(self):
  
        return 'The average amount of Revenue for ' + self.state +  " between 2000 - 2015 is $"  + str(self.average)
    
       
IL_rAVG = CalcAvg( "Illinois", IL_revA)
print (IL_rAVG)

IN_rAVG = CalcAvg( "Indiana", IN_revA)
print (IN_rAVG)

IW_rAVG = CalcAvg( "Iowa", IW_revA)
print (IW_rAVG)

KS_rAVG = CalcAvg( "Kansas", KS_revA)
print (KS_rAVG)

MI_rAVG = CalcAvg( "Michigan", MI_revA)
print (MI_rAVG)

MN_rAVG = CalcAvg( "Minnesota", MN_revA)
print (MN_rAVG)

MO_rAVG = CalcAvg( "Missouri", MO_revA)
print (MO_rAVG)

NE_rAVG = CalcAvg( "Nebraska", NE_revA)
print (NE_rAVG)

ND_rAVG = CalcAvg( "North Dakota", ND_revA)
print (ND_rAVG)

OH_rAVG = CalcAvg( "Ohio", OH_revA)
print (OH_rAVG)

SD_rAVG = CalcAvg( "South Dakota", SD_revA)
print (SD_rAVG)

WI_rAVG = CalcAvg( "Wisconsin", WI_revA)
print (WI_rAVG)
# Out:
# The average amount of Revenue for Illinois between 2000 - 2015 is $26,255,058.14
# The average amount of Revenue for Indiana between 2000 - 2015 is $11,083,245.00
# The average amount of Revenue for Iowa between 2000 - 2015 is $5,357,057.50
# The average amount of Revenue for Kansas between 2000 - 2015 is $4,957,729.25
# The average amount of Revenue for Michigan between 2000 - 2015 is $19,208,266.43
# The average amount of Revenue for Minnesota between 2000 - 2015 is $9,762,404.62
# The average amount of Revenue for Missouri between 2000 - 2015 is $8,957,803.25
# The average amount of Revenue for Nebraska between 2000 - 2015 is $3,314,395.62
# The average amount of Revenue for North Dakota between 2000 - 2015 is $1,152,520.12
# The average amount of Revenue for Ohio between 2000 - 2015 is $21,052,301.75
# The average amount of Revenue for South Dakota between 2000 - 2015 is $1,164,039.00
# The average amount of Revenue for Wisconsin between 2000 - 2015 is $10,238,643.62

# %%
from operator import itemgetter
from collections import OrderedDict

#I want to first start with compiling a list of all the averages for expenditure and revenue.
L_REV = {"ND" : ND_revA, "SD":  SD_revA, "NE": NE_revA, "KS": KS_revA, "IW":IW_revA,  "MO":MO_revA, "MN":MN_revA, "WI" :WI_revA, "IN": IN_revA, "MI":MI_revA, "OH": OH_revA,  "IL" : IL_revA}

print(L_REV)

L_EXP = {"SD" : SD_expenditureA,  "ND": ND_expenditureA,  "NE": NE_expenditureA, "KS": KS_expenditureA, "IW": IW_expenditureA,  "MO":MO_expenditureA, "MN":MN_expenditureA, "WI": WI_expenditureA, "IN": IN_expenditureA, "MI": MI_expenditureA, "OH" : OH_expenditureA, "IL" : IL_expenditureA}

print(L_EXP)

# I have sorted them in increasing order with the help of excel, as I was having trouble doing this in Python with using a dictionary.
# Out:
# {'ND': '1,152,520.12', 'SD': '1,164,039.00', 'NE': '3,314,395.62', 'KS': '4,957,729.25', 'IW': '5,357,057.50', 'MO': '8,957,803.25', 'MN': '9,762,404.62', 'WI': '10,238,643.62', 'IN': '11,083,245.00', 'MI': '19,208,266.43', 'OH': '21,052,301.75', 'IL': '26,255,058.14'}
# {'SD': '1,183,715.50', 'ND': '1,187,068.25', 'NE': '3,251,651.88', 'KS': '4,916,625.25', 'IW': '5,396,462.75', 'MO': '9,080,313.12', 'MN': '10,063,233.75', 'WI': '10,181,730.50', 'IN': '10,718,917.50', 'MI': '19,097,626.43', 'OH': '20,600,961.88', 'IL': '26,412,224.57'}

# %%
import matplotlib
from matplotlib import pyplot as plt

AvgRevenueByState = plt.bar( range(len(L_REV)),L_REV.values(), align='center') 
plt.xticks(range(len(L_REV)), list(L_REV.keys()))
plt.title("Average Revenue per State from 2000 - 2015")
plt.xlabel("State")
plt.ylabel("Revenue")
plt.show()

AvgExpenseByState = plt.bar( range(len(L_EXP)),L_EXP.values(), align='center') 
plt.xticks(range(len(L_EXP)), list(L_EXP.keys()))
plt.title("Average Expense per State from 2000 - 2015")
plt.xlabel("State")
plt.ylabel("EXPENSE")
plt.show()

# so the revenue and expense is relativley within the same range in average in all 12 states.

# %%
#Next I will graph all reading scores for the 12 states from 2000-2015 and will examine in detail the minimum values and maximum values for the scores in different years.
from numpy import *
import math
import matplotlib.pyplot as plt

ILReading = plt.plot(il.YEAR, il.AVG_READING_8_SCORE) # blue
OHReading = plt.plot(oh.YEAR, oh.AVG_READING_8_SCORE) # orange
MNReading = plt.plot(mn.YEAR, mn.AVG_READING_8_SCORE) #green
WIReading = plt.plot(wi.YEAR, wi.AVG_READING_8_SCORE) #red
MIReading = plt.plot(mi.YEAR, mi.AVG_READING_8_SCORE) #purple
INReading = plt.plot(indy.YEAR, indy.AVG_READING_8_SCORE) #brown
plt.title("Average Reading Scores - 8TH GRADE") 
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

NEReading = plt.plot(nb.YEAR, nb.AVG_READING_8_SCORE) # blue
ksReading = plt.plot(ks.YEAR, ks.AVG_READING_8_SCORE) # orange
IWReading = plt.plot(iw.YEAR, iw.AVG_READING_8_SCORE) #green
MOReading = plt.plot(mo.YEAR, mo.AVG_READING_8_SCORE) #red
SDReading = plt.plot(sd.YEAR, sd.AVG_READING_8_SCORE) #purple
NDReading = plt.plot(nd.YEAR, nd.AVG_READING_8_SCORE) #brown
plt.title("Average Reading Scores - 8TH GRADE") 
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

# %%
import matplotlib
from matplotlib import pyplot as plt
# I plotted each graph by state to compare revenue and expense along with the reading score reported. 

ILReading = plt.plot(il.YEAR, il.AVG_READING_8_SCORE) 
plt.title("IL Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ILExp = plt.plot(il.YEAR, il.TOTAL_EXPENDITURE) #blue
ILREV = plt.plot(il.YEAR, il.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for IL")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()


################################################

nbReading = plt.plot(nb.YEAR, nb.AVG_READING_8_SCORE) 

plt.title("Neberaska Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

nbExp = plt.plot(nb.YEAR, nb.TOTAL_EXPENDITURE)#blue
nbREV = plt.plot(nb.YEAR, nb.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Nebereska")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

MOReading = plt.plot(mo.YEAR, mo.AVG_READING_8_SCORE) 
plt.title("MO Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

MOExp = plt.plot(mo.YEAR, mo.TOTAL_EXPENDITURE)#blue
moREV = plt.plot(mo.YEAR, mo.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Moussouri")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

IWReading = plt.plot(iw.YEAR, iw.AVG_READING_8_SCORE) 
plt.title("IW Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

IWExp = plt.plot(iw.YEAR, iw.TOTAL_EXPENDITURE)#blue
IWREV = plt.plot(iw.YEAR, iw.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Iowa")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()


################################################

miReading = plt.plot(mi.YEAR, mi.AVG_READING_8_SCORE) 
plt.title("MI Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

miExp = plt.plot(mi.YEAR, mi.TOTAL_EXPENDITURE) #blue
miREV = plt.plot(mi.YEAR, mi.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Michigan")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

sdReading = plt.plot(sd.YEAR, sd.AVG_READING_8_SCORE) 
plt.title("SD Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

sdExp = plt.plot(sd.YEAR, sd.TOTAL_EXPENDITURE) #blue
sdREV = plt.plot(sd.YEAR, sd.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for South Dakota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

ndReading = plt.plot(nd.YEAR, nd.AVG_READING_8_SCORE) 
plt.title("ND Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ndExp = plt.plot(nd.YEAR, nd.TOTAL_EXPENDITURE) #blue
ndREV = plt.plot(nd.YEAR, nd.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for North Dakota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

################################################

indyReading = plt.plot(indy.YEAR, indy.AVG_READING_8_SCORE) 
plt.title("INDY Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

indyExp = plt.plot(indy.YEAR, indy.TOTAL_EXPENDITURE)#blue
indyREV = plt.plot(indy.YEAR, indy.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for INDIANA")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


OhReading = plt.plot(oh.YEAR, oh.AVG_READING_8_SCORE) 
plt.title("Ohio Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

OHExp = plt.plot(oh.YEAR, oh.TOTAL_EXPENDITURE) #blue
OHREV = plt.plot(oh.YEAR, oh.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Ohio")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


wiReading = plt.plot(wi.YEAR, wi.AVG_READING_8_SCORE) 
plt.title("Wisconsin Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

wiExp = plt.plot(wi.YEAR, wi.TOTAL_EXPENDITURE) #blue
WIREV = plt.plot(wi.YEAR, wi.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Wisconsin")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


mnReading = plt.plot(mn.YEAR, mn.AVG_READING_8_SCORE) 
plt.title("MN Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

mnExp = plt.plot(mn.YEAR, mn.TOTAL_EXPENDITURE)#blue
mnREV = plt.plot(mn.YEAR, mn.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Minnisota")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()

#################################################


ksReading = plt.plot(ks.YEAR, ks.AVG_READING_8_SCORE) 
plt.title("Kansas Reading Scores - 8TH GRADE")
plt.xlabel("Year")
plt.ylabel("Test Grades ")
plt.show()

ksExp = plt.plot(ks.YEAR, ks.TOTAL_EXPENDITURE)#blue
ksREV = plt.plot(ks.YEAR, ks.TOTAL_REVENUE) #orange
plt.title("Expenditure and Revenue for Kansas")
plt.xlabel("Year")
plt.ylabel("Expense ")
plt.show()
